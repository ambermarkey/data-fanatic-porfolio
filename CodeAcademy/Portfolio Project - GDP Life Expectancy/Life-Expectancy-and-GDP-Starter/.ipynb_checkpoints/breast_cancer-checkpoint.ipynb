# %% [markdown]
# ## Project Scope
#
# ### Goals
#
# * A greater understanding of statistical methods
# * Practice visualizing and presenting data
# * Understand which characteristics of a tumor have the highest correlation to benign and malignant tumor classification
#
# ### Data
# Breast Cancer Wisconsin (Diagnostic) Data Set
#
# _Predict whether the cancer is benign or malignant_

# %% [markdown]
# ### Data Description
# Attribute Information:
#
# 1) ID number
# 2) Diagnosis (M = malignant, B = benign)
# 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter)
# b) texture (standard deviation of gray-scale values)
# c) perimeter
# d) area
# e) smoothness (local variation in radius lengths)
# f) compactness (perimeter^2 / area - 1.0)
# g) concavity (severity of concave portions of the contour)
# h) concave points (number of concave portions of the contour)
# i) symmetry
# j) fractal dimension ("coastline approximation" - 1)
#
# The mean, standard error and "worst" or largest (mean of the three
# largest values) of these features were computed for each image,
# resulting in 30 features. For instance, field 3 is Mean Radius, field
# 13 is Radius SE, field 23 is Worst Radius.
#
# All feature values are recoded with four significant digits.
#
# Missing attribute values: none

# %%
# Importing Libraries for use in the analysis

import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import matplotlib.pyplot as plt
import math
from scipy.stats import pearsonr, ttest_rel

# %%
# Preview the dataset

dataset = pd.read_csv('data.csv')
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #### Notes
#
# Looking at the first few lines, there are a couple of columns with data that will not add to the analysis. The first 'Unnamed: 32' contains only NaN and the other, 'id', appears to be an identifier for the patient with no additional information coded in.

# %%
# Dropping columns containing unimportant data
drop_list = ['id', 'Unnamed: 32']
dataset = dataset.drop(drop_list, axis = 1)
dataset.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# It will be helpful to have two separate datasets for benign and malignant tumors

# %%
# splitting the dataset into benign and malignant data

benign = dataset[dataset.diagnosis == 'B']
malignant = dataset[dataset.diagnosis == 'M']

#benign = benign.drop('diagnosis', axis = 1)
#malignant = malignant.drop('diagnosis', axis = 1)

print('The breakdown of the data includes ' + str(len(benign)) + ' datapoints on benign tumors and ' + str(len(malignant)) + ' datapoints on malignant tumors.')
# Out:
# The breakdown of the data includes 357 datapoints on benign tumors and 212 datapoints on malignant tumors.

# %% [markdown]
# Since the data is not evenly split, when looking at histograms of the data, I will want to normalize the data.
#
# Let's take a look at the summary statistics for both malignant and benign datasets.

# %%
benign.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean   area_mean  smoothness_mean  \
# count   357.000000    357.000000      357.000000  357.000000       357.000000
# mean     12.146524     17.914762       78.075406  462.790196         0.092478
# std       1.780512      3.995125       11.807438  134.287118         0.013446
# min       6.981000      9.710000       43.790000  143.500000         0.052630
# 25%      11.080000     15.150000       70.870000  378.200000         0.083060
# 50%      12.200000     17.390000       78.180000  458.400000         0.090760
# 75%      13.370000     19.760000       86.100000  551.100000         0.100700
# max      17.850000     33.810000      114.600000  992.100000         0.163400
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# count        357.000000      357.000000           357.000000     357.000000
# mean           0.080085        0.046058             0.025717       0.174186
# ...

# %%
malignant.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   212.000000    212.000000      212.000000   212.000000
# mean     17.462830     21.604906      115.365377   978.376415
# std       3.203971      3.779470       21.854653   367.937978
# min      10.950000     10.380000       71.900000   361.600000
# 25%      15.075000     19.327500       98.745000   705.300000
# 50%      17.325000     21.460000      114.200000   932.000000
# 75%      19.590000     23.765000      129.925000  1203.750000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       212.000000        212.000000      212.000000           212.000000
# mean          0.102898          0.145188        0.160775             0.087990
# std           0.012608          0.053987        0.075019             0.034374
# min           0.073710          0.046050        0.023980             0.020310
# ...

# %% [markdown]
# A few things to note:
# 1. The data appears to be in the correct format (but will double check that)
# 2. It appears that there may be outliers in both datasets
# 3.

# %%
# Grabbing the column names for use in creating charts
columns = dataset.columns.to_list()
columns.remove('diagnosis')
print(columns)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
for column in columns:
    plt.hist(benign[column], bins = 20, color = 'red', density = True, alpha = 0.5)
    plt.hist(malignant[column], bins = 20, color = 'blue', density = True, alpha = 0.5)
    title = 'Histogram of {}'
    plt.title(title.format(column))
    plt.legend(['benign', 'malignant'])
    plt.show()
    plt.clf()

# %% [markdown]
# Let's take a deeper dive on the characteristics with distinctly different values between malignant and benign...
#
# Distinctly different Characteristics:
# * radius_mean
# * texture_mean
# * perimeter_mean
# * area_mean
# * compactness_mean
# * concavity_mean
# * concave points_mean
#
# How well correlated are mean, se, and worst values?
#
# It would be interesting to look at a couple of others that have slightly shifted peaks to determine if the shift is significant or not.
# * concave points_se
# * perimeter_se

# %%
# Starting with the t-test on the two sets above..
# Note, the distribution is slightly skewed. However, with a large sample size (>50), the t-test can be used to test the null hypothesis.

benign_concave_se = benign['concave points_se'].sample(n = 212)

ttest_rel(benign_concave_se, malignant['concave points_se'])
# Out:
# Ttest_relResult(statistic=-8.97013929072543, pvalue=1.6284278992943951e-16)

# %%
benign_perimeter_se = benign['perimeter_se'].sample(n=212)
ttest_rel(benign_perimeter_se, malignant['perimeter_se'])
# Out:
# Ttest_relResult(statistic=-12.419304029984772, pvalue=6.0761074231603595e-27)

# %% [markdown]
# From the relative T-Test, the pvalues show that there is significant difference between the two that, in the histogram, do not seem significant! Cool...
#
# Double checking with a set of data that is clearly insignificantly different.

# %%
# let's double check the process and assumptions here...
benign_fractal = benign['fractal_dimension_mean'].sample(n = 212)
ttest_rel(benign_fractal, malignant['fractal_dimension_mean'])
# Out:
# Ttest_relResult(statistic=-0.06179087712633461, pvalue=0.950787859513467)

# %% [markdown]
# It would also be helpful to check out the correlation between values. Do the mean, se, and worst values correlate or should all of those be included as possible values to predict malignant or benign from?

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(benign.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(malignant.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Measurements of size and area are well-correlated, it wouldn't be as helpful to look through all of those. However, the rest of the mean, se, and worst values should be included in the overall analysis.
#
# It would be helpful to visualize several measurements in a single figure. But, to do so, the data should be normalized in order to plot values with a wide range of values on a single plot.
#
# To standardize the data, looking at the range in relation to the standard deviation of each dataset will give us a good idea of each characteristic across the full spectrum of data available. [update] The formula to standardize the data factors in the standard deviation and the mean of the data such that the new representation presents each data point as the number of standard deviations from the mean.
#
# The STANDARDIZE function uses the following formula to normalize a given data value:
#
# Normalized value = (x – x_bar) / s
#
# where:
#
# * x = data value
# * x_bar = mean of dataset
# * s = standard deviation of dataset

# %%
# Standardize the data.
for column in columns:
    benign_std[column] = (benign[column] - benign[column].mean())/benign[column].std()
    malignant_std[column] = (malignant[column] - malignant[column].mean())/malignant[column].std()
    
# cursory check...
benign_std.head()
# Out:
#     area_mean   area_se  area_worst  compactness_mean  compactness_se  \
# 19   0.770810  0.274197    0.930924          0.035715       -0.418203
# 20   0.426026 -0.731064    0.437652          1.390087       -0.150338
# 21  -1.406614 -0.614594   -1.491426         -0.449323       -0.435327
# 37   0.454324 -0.788734   -0.079458         -1.257028       -1.011481
# 46  -1.942779 -1.462112   -1.935799         -0.611990       -0.304452
#
#     compactness_worst  concave points_mean  concave points_se  \
# 19          -0.058283             1.388705           0.576732
# 20           1.029806             0.338341          -0.589924
# 21          -0.736305            -0.311615           0.762416
# 37          -1.480609             0.220796           0.312220
# 46          -0.509574            -1.244621          -0.690298
#
#     concave points_worst  concavity_mean  ...  radius_worst  smoothness_mean  \
# 19              1.518426        0.473788  ...      0.873235         0.395086
# ...

# %% [markdown]
# Now, to compare across characteristics, boxplots will give us a good idea of how benign and malignant data compare across the board.

# %%
plt.figure(figsize = (12,12))
